# %%
import pandas as pd

# %%
df = pd.read_csv("listings.csv")

# %%
print(df)
# Out:
#                         id                                       listing_url  \
# 0                     5456                 https://www.airbnb.com/rooms/5456
# 1                     5769                 https://www.airbnb.com/rooms/5769
# 2                     6413                 https://www.airbnb.com/rooms/6413
# 3                     6448                 https://www.airbnb.com/rooms/6448
# 4                     8502                 https://www.airbnb.com/rooms/8502
# ...                    ...                                               ...
# 15414  1046385356940054475  https://www.airbnb.com/rooms/1046385356940054475
# 15415  1046411773158637914  https://www.airbnb.com/rooms/1046411773158637914
# 15416  1046446724556255368  https://www.airbnb.com/rooms/1046446724556255368
# 15417  1046490684531759639  https://www.airbnb.com/rooms/1046490684531759639
# 15418  1046491941158053171  https://www.airbnb.com/rooms/1046491941158053171
#
# ...
